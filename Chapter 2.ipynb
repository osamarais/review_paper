# %%
# #!/usr/bin/python3

# import qiskit

# # Create a register of 3 qubits, with a label myQubits
# myRegister = qiskit.QuantumRegister(3, 'myQubits')

# %%
#!/usr/bin/python3

import qiskit

# Create a register of 3 qubits
myQRegister = qiskit.QuantumRegister(3, '\psi')

# Create a register of 3 classical bits
myCRegister = qiskit.ClassicalRegister(3,'Classical Bits')

# Create a quantum circuit with using myRegister
myCircuit = qiskit.QuantumCircuit(myQRegister, myCRegister)

# Add the gates in order of operation
myCircuit.h(2)
myCircuit.x(0)
myCircuit.cnot(2,1)

# Insert a barrier to keep circuit organized
myCircuit.barrier()

# Measure all the qubits in myQRegister and store state in myCRegister
myCircuit.measure(myQRegister,myCRegister)

# Draw the circuit
print(myCircuit.draw('latex_source'))
myCircuit.draw('latex')

# # Draw the circuit
# myCircuit = myCircuit.reverse_bits()
# print(myCircuit.draw('latex_source'))
# myCircuit.draw('latex')
# Out:
# \documentclass[border=2px]{standalone}
#
# \usepackage[braket, qm]{qcircuit}
# \usepackage{graphicx}
#
# \begin{document}
# \scalebox{1.0}{
# \Qcircuit @C=1.0em @R=0.2em @!R { \\
# 	 	\nghost{{\psi}_{0} :  } & \lstick{{\psi}_{0} :  } & \gate{\mathrm{X}} & \qw \barrier[0em]{2} & \qw & \meter & \qw & \qw & \qw & \qw\\
# 	 	\nghost{{\psi}_{1} :  } & \lstick{{\psi}_{1} :  } & \qw & \targ & \qw & \qw & \meter & \qw & \qw & \qw\\
# 	 	\nghost{{\psi}_{2} :  } & \lstick{{\psi}_{2} :  } & \gate{\mathrm{H}} & \ctrl{-1} & \qw & \qw & \qw & \meter & \qw & \qw\\
# 	 	\nghost{\mathrm{{Classical\;Bits} :  }} & \lstick{\mathrm{{Classical\;Bits} :  }} & \lstick{/_{_{3}}} \cw & \cw & \cw & \dstick{_{_{\hspace{0.0em}0}}} \cw \ar @{<=} [-3,0] & \dstick{_{_{\hspace{0.0em}1}}} \cw \ar @{<=} [-2,0] & \dstick{_{_{\hspace{0.0em}2}}} \cw \ar @{<=} [-1,0] & \cw & \cw\\
# \\ }}
# \end{document}
# <PIL.Image.Image image mode=RGB size=466x138>

# %%
#!/usr/bin/python3

import qiskit

# Create a register of 3 qubits
myQRegister = qiskit.QuantumRegister(3, '\psi')

# Create a register of 3 classical bits
myCRegister = qiskit.ClassicalRegister(3,'Classical Bits')

# Create a quantum circuit with using myRegister
myCircuit = qiskit.QuantumCircuit(myQRegister, myCRegister)

# Start working in big-endian order

# Add the gates in order of operation
myCircuit.h(0)
myCircuit.x(2)
myCircuit.cnot(0,1,ctrl_state='1')

# Insert a barrier to keep circuit organized
myCircuit.barrier()

# Measure all the qubits in myQRegister and store state in myCRegister
myCircuit.measure(myQRegister,myCRegister)

# Convert from big-endian to little-endian by reversing bits
myCircuit = myCircuit.reverse_bits()

# Draw the circuit
print(myCircuit.draw('latex_source'))
myCircuit.draw('latex')
# Out:
# \documentclass[border=2px]{standalone}
#
# \usepackage[braket, qm]{qcircuit}
# \usepackage{graphicx}
#
# \begin{document}
# \scalebox{1.0}{
# \Qcircuit @C=1.0em @R=0.2em @!R { \\
# 	 	\nghost{{\psi}_{0} :  } & \lstick{{\psi}_{0} :  } & \gate{\mathrm{X}} & \qw \barrier[0em]{2} & \qw & \qw & \qw & \meter & \qw & \qw\\
# 	 	\nghost{{\psi}_{1} :  } & \lstick{{\psi}_{1} :  } & \qw & \targ & \qw & \qw & \meter & \qw & \qw & \qw\\
# 	 	\nghost{{\psi}_{2} :  } & \lstick{{\psi}_{2} :  } & \gate{\mathrm{H}} & \ctrl{-1} & \qw & \meter & \qw & \qw & \qw & \qw\\
# 	 	\nghost{\mathrm{{Classical\;Bits} :  }} & \lstick{\mathrm{{Classical\;Bits} :  }} & \lstick{/_{_{3}}} \cw & \cw & \cw & \dstick{_{_{\hspace{0.0em}0}}} \cw \ar @{<=} [-1,0] & \dstick{_{_{\hspace{0.0em}1}}} \cw \ar @{<=} [-2,0] & \dstick{_{_{\hspace{0.0em}2}}} \cw \ar @{<=} [-3,0] & \cw & \cw\\
# \\ }}
# \end{document}
# <PIL.Image.Image image mode=RGB size=466x138>

# %%
#!/usr/bin/python3

import qiskit

# Create a register of 3 qubits
myQRegister = qiskit.QuantumRegister(2, '\psi')


# Create a quantum circuit with using myRegister
myCircuit = qiskit.QuantumCircuit(myQRegister)

# Add the gates in order of operation
myCircuit.cnot(0,1,ctrl_state='1')
myCircuit.cnot(0,1,ctrl_state='0')

# Draw the circuit
print(myCircuit.draw('latex_source'))
myCircuit.draw('latex')

# # Draw the circuit
# myCircuit = myCircuit.reverse_bits()
# print(myCircuit.draw('latex_source'))
# myCircuit.draw('latex')
# Out:
# \documentclass[border=2px]{standalone}
#
# \usepackage[braket, qm]{qcircuit}
# \usepackage{graphicx}
#
# \begin{document}
# \scalebox{1.0}{
# \Qcircuit @C=1.0em @R=0.2em @!R { \\
# 	 	\nghost{{\psi}_{0} :  } & \lstick{{\psi}_{0} :  } & \ctrl{1} & \ctrlo{1} & \qw & \qw\\
# 	 	\nghost{{\psi}_{1} :  } & \lstick{{\psi}_{1} :  } & \targ & \targ & \qw & \qw\\
# \\ }}
# \end{document}
# <PIL.Image.Image image mode=RGB size=162x41>

# %%
#!/usr/bin/python3

import qiskit
from qiskit import Aer
from qiskit.tools.visualization import plot_histogram

# Create a register of 3 qubits
myQRegister = qiskit.QuantumRegister(3, '\psi')

# Create a register of 3 classical bits
myCRegister = qiskit.ClassicalRegister(3,'Classical Bits')

# Create a quantum circuit with using myRegister
myCircuit = qiskit.QuantumCircuit(myQRegister, myCRegister)

# Hadamard gates on al qubits
myCircuit.h(myQRegister)

# Measure all the qubits in myQRegister and store state in myCRegister
myCircuit.measure(myQRegister,myCRegister)


# Simulate the circuit
mySimulator = Aer.get_backend('aer_simulator')
result = mySimulator.run(myCircuit,shots=5120).result()

# Plot a bar chart of all the results
plot_histogram(result.get_counts(), title='Uniform Superposition')

# %%
#!/usr/bin/python3

import qiskit
from qiskit import Aer
from qiskit.tools.visualization import plot_histogram

# Create a register of 2 qubits
myQRegister = qiskit.QuantumRegister(2, '\psi')

# Create a register of 2 classical bits
myCRegister = qiskit.ClassicalRegister(2,'Classical Bits')

# Create a quantum circuit with using myRegister
myCircuit = qiskit.QuantumCircuit(myQRegister, myCRegister)

# Hadamard gates on al qubits
myCircuit.h(0)
myCircuit.cnot(0,1)

# Measure all the qubits in myQRegister and store state in myCRegister
myCircuit.measure(myQRegister,myCRegister)


# Simulate the circuit
mySimulator = Aer.get_backend('aer_simulator')
result = mySimulator.run(myCircuit,shots=5120).result()

print(myCircuit.draw('latex_source'))

# Plot a bar chart of all the results
plot_histogram(result.get_counts(), title='Bell State')
# Out:
# \documentclass[border=2px]{standalone}
#
# \usepackage[braket, qm]{qcircuit}
# \usepackage{graphicx}
#
# \begin{document}
# \scalebox{1.0}{
# \Qcircuit @C=1.0em @R=0.2em @!R { \\
# 	 	\nghost{{\psi}_{0} :  } & \lstick{{\psi}_{0} :  } & \gate{\mathrm{H}} & \ctrl{1} & \meter & \qw & \qw & \qw\\
# 	 	\nghost{{\psi}_{1} :  } & \lstick{{\psi}_{1} :  } & \qw & \targ & \qw & \meter & \qw & \qw\\
# 	 	\nghost{\mathrm{{Classical\;Bits} :  }} & \lstick{\mathrm{{Classical\;Bits} :  }} & \lstick{/_{_{2}}} \cw & \cw & \dstick{_{_{\hspace{0.0em}0}}} \cw \ar @{<=} [-2,0] & \dstick{_{_{\hspace{0.0em}1}}} \cw \ar @{<=} [-1,0] & \cw & \cw\\
# \\ }}
# \end{document}

# %%
#!/usr/bin/python3

import qiskit
from qiskit import Aer
from qiskit.tools.visualization import plot_histogram

# Create a register of 1 qubits
myQRegister = qiskit.QuantumRegister(1, '\psi \otimes')

# Create a quantum circuit with using myRegister
myCircuit = qiskit.QuantumCircuit(myQRegister)

# Hadamard gates on al qubits
myCircuit.h(0)
myCircuit.h(0)

print(myCircuit.draw('latex_source'))
# Out:
# \documentclass[border=2px]{standalone}
#
# \usepackage[braket, qm]{qcircuit}
# \usepackage{graphicx}
#
# \begin{document}
# \scalebox{1.0}{
# \Qcircuit @C=1.0em @R=0.2em @!R { \\
# 	 	\nghost{{\psi\;\otimes} :  } & \lstick{{\psi\;\otimes} :  } & \gate{\mathrm{H}} & \gate{\mathrm{H}} & \qw & \qw\\
# \\ }}
# \end{document}

# %%
#!/usr/bin/python3

import qiskit
from qiskit import Aer
from scipy.linalg import expm
import numpy as np
import matplotlib.pyplot as plt

# Calculate exact solution classically
exact_solution = expm( - 1j * ( np.array([[0, 1], [1, 0]])
      + np.array([[1, 0], [0, -1]]) ) )

t = 1
m = [10,20,40,80]

errors = []
for r in m:
    # Create a register of 1 qubit
    myQRegister = qiskit.QuantumRegister(1, '\psi')

    # Create a quantum circuit with using myRegister
    myCircuit = qiskit.QuantumCircuit(myQRegister)
    for _r in range(r):
        myCircuit.rx(t*2/r,0)
        myCircuit.rz(t*2/r,0)

    # Simulate the circuit to obtain overall unitary of Trotterization
    mySimulator = Aer.get_backend('unitary_simulator')
    result = mySimulator.run(myCircuit).result()
    finalUnitary = result.get_unitary()
    
    # Compare circuit unitary with exact unitary
    errors.append( np.linalg.norm(finalUnitary - exact_solution,2) )

plt.loglog(m,errors)
plt.xlabel('# of Trotter steps')
plt.ylabel('|error|_2')
# Out:
# Text(0, 0.5, '|error|_2')

# %%
#!/usr/bin/python3

import qiskit
from qiskit import Aer
from scipy.linalg import expm
import numpy as np
import matplotlib.pyplot as plt

min_t = 1
max_t = 5

# Number of Trotter Steps
m = [10,20,40,80,100, 200, 400, 800, 1000, 2000, 4000, 8000, 10000]

# First order Trotter
for t in range(min_t,max_t+1):
    # Calculate exact solution classically
    exact_solution = expm( -t * 1j * ( np.array([[0, 1], [1, 0]])
      + np.array([[1, 0], [0, -1]]) ) )

    errors = []
    for r in m:
        # Create a register of 1 qubit
        myQRegister = qiskit.QuantumRegister(1, '\psi')

        # Create a quantum circuit with using myRegister
        myCircuit = qiskit.QuantumCircuit(myQRegister)
        for _r in range(r):
            myCircuit.rx(t*2/r,0)
            myCircuit.rz(t*2/r,0)

        # Simulate the circuit to obtain overall unitary of Trotterization
        mySimulator = Aer.get_backend('unitary_simulator')
        result = mySimulator.run(myCircuit).result()
        finalUnitary = result.get_unitary()

        # Compare circuit unitary with exact unitary
        errors.append( np.linalg.norm(finalUnitary - exact_solution,2) )

    plt.loglog(m,errors)
    
    
# 2nd order Trotter
for t in range(min_t,max_t+1):
    # Calculate exact solution classically
    exact_solution = expm( -t * 1j * ( np.array([[0, 1], [1, 0]])
      + np.array([[1, 0], [0, -1]]) ) )

    errors = []
    for r in m:
        # Create a register of 1 qubit
        myQRegister = qiskit.QuantumRegister(1, '\psi')

        # Create a quantum circuit with using myRegister
        myCircuit = qiskit.QuantumCircuit(myQRegister)
        for _r in range(r):
            myCircuit.rx(t/r,0)
            myCircuit.rz(t*2/r,0)
            myCircuit.rx(t/r,0)
            

        # Simulate the circuit to obtain overall unitary of Trotterization
        mySimulator = Aer.get_backend('unitary_simulator')
        result = mySimulator.run(myCircuit).result()
        finalUnitary = result.get_unitary()

        # Compare circuit unitary with exact unitary
        errors.append( np.linalg.norm(finalUnitary - exact_solution,2) )

    plt.loglog(m,errors,linestyle='dashed')

plt.xlabel('# of Trotter steps')
plt.ylabel('|error|_2')
plt.legend(['t = {}, 1st Order'.format(t) for t in range(min_t,max_t+1)]
                   +['t = {}, 2nd Order'.format(t) for t in range(min_t,max_t+1)])

# %%
#!/usr/bin/python3

import qiskit
from qiskit import Aer
from qiskit.tools.visualization import plot_histogram
from qiskit.circuit.library import QFT

n_qubits = 5

myQRegister = qiskit.QuantumRegister(n_qubits)
myCircuit = qiskit.QuantumCircuit(myQRegister)
myCircuit.initialize('01000')

# Create a quantum circuit with using myRegister
# qFT = QFT(n_qubits,inverse=True).to_gate()
# myCircuit.append(qFT)

# type(qFT)
# myCircuit.measure_all()

# myCircuit.transpile()

myCircuit.draw('latex')




# # Simulate the circuit
# mySimulator = Aer.get_backend('statevector_simulator')
# result = mySimulator.run(myCircuit,shots=5120).result()

# # Plot a bar chart of all the results
# plot_histogram(result.get_counts())
# Out:
# <PIL.Image.Image image mode=RGB size=278x184>

# %%
Aer.aer.backends()
# Out:
# [AerSimulator('aer_simulator'),
#  AerSimulator('aer_simulator_statevector'),
#  AerSimulator('aer_simulator_density_matrix'),
#  AerSimulator('aer_simulator_stabilizer'),
#  AerSimulator('aer_simulator_matrix_product_state'),
#  AerSimulator('aer_simulator_extended_stabilizer'),
#  AerSimulator('aer_simulator_unitary'),
#  AerSimulator('aer_simulator_superop'),
#  QasmSimulator('qasm_simulator'),
#  StatevectorSimulator('statevector_simulator'),
#  UnitarySimulator('unitary_simulator'),
#  PulseSimulator('pulse_simulator')]

# %%
myCircuit.initialize

# %%
myCircuit.h(0)

# %%
myCircuit = myCircuit.compose(myCircuit)

# %%
myCircuit.draw()
# Out:
#      ┌──────┐┌───┐┌──────┐┌───┐
# q_0: ┤0     ├┤ H ├┤0     ├┤ H ├
#      │      │└───┘│      │└───┘
# q_1: ┤1     ├─────┤1     ├─────
#      │      │     │      │
# q_2: ┤2 QFT ├─────┤2 QFT ├─────
#      │      │     │      │
# q_3: ┤3     ├─────┤3     ├─────
#      │      │     │      │
# q_4: ┤4     ├─────┤4     ├─────
#      └──────┘     └──────┘

# %%
from qiskit import QuantumCircuit
from qiskit.circuit.library import QFT

qc = QuantumCircuit(5)
# qc.initialize('0000')
qc.h([0,1,2,3,4])
qft = QFT(num_qubits=5).to_gate()
qc.append(qft, qargs=[0,1,2,3,4])


qc.measure_all()

qc = qc.decompose(reps=2)

qc.draw('latex')



# # Simulate the circuit
mySimulator = Aer.get_backend('aer_simulator')
result = mySimulator.run(qc,shots=1024).result()

# Plot a bar chart of all the results
plot_histogram(result.get_counts())

# %%
#!/usr/bin/python3

from matplotlib import pyplot as plt
from qiskit import QuantumCircuit
from qiskit.circuit.library import QFT
from qiskit import Aer
from qiskit.tools.visualization import plot_histogram

beforeFT = QuantumCircuit(5)
# Initialize state in uniform superposition
beforeFT.h([0,1,2,3,4])

# Measure all qubits
beforeFT.measure_all()

# Simulate the circuit
mySimulator = Aer.get_backend('aer_simulator')
result = mySimulator.run(beforeFT,shots=2**20).result()

# Plot a bar chart of all the results
plot_histogram(result.get_counts(),bar_labels=False,title='Before QFT')

# %%
afterFT = QuantumCircuit(5)
# Initialize qubits
afterFT.h([0,1,2,3,4])

# Add Fourier transform operation
qft = QFT(num_qubits=5,do_swaps=False).to_gate()
afterFT.append(qft, qargs=[0,1,2,3,4])

# Measure all qubits
afterFT.measure_all()

# Decompose Fourier transform operation into gates for simulator
afterFT = afterFT.decompose(reps=2)

# # Simulate the circuit
result = mySimulator.run(afterFT,shots=2**20).result()

# Plot a bar chart of all the results
plot_histogram(result.get_counts(),bar_labels=False,title='After QFT')

# %%
#!/usr/bin/python3

from matplotlib import pyplot as plt
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.circuit.library import QFT

# Create the clock register for control qubits
clockRegisterSize = 4
clockRegister = QuantumRegister(clockRegisterSize,name='Clock Register')

# Create a classical register to store the result
clockRegisterOutput = ClassicalRegister(clockRegisterSize,name='Output')

# Create a work register that works on the input
workRegisterSize = 1
workRegister = QuantumRegister(workRegisterSize,name='Work Register')

# An arbitrary unitary (quantum circuit) applied to the input
# a.k.a. a black box
U = QuantumCircuit(workRegister,name='U').to_gate()
# cU = U.control(4)

# The overall circuit for phase estimation
myCircuit = QuantumCircuit(clockRegister, workRegister,clockRegisterOutput)

# Initialize state in uniform superposition
myCircuit.h(clockRegister)
# Apply controlled versions of powers of the black box operation
for i,controlBit in enumerate(reversed(clockRegister)):
    myCircuit.append((U**(2**i)).control(1),[controlBit]+workRegister[:])

# Apply the inverse Fourier transform
qft = QFT(num_qubits=clockRegisterSize,inverse=True).to_gate()
myCircuit.append(qft, qargs=clockRegister)

# myCircuit.barrier()
myCircuit.measure(clockRegister,clockRegisterOutput)

print(myCircuit.draw('latex_source'))
# Out:
# \documentclass[border=2px]{standalone}
#
# \usepackage[braket, qm]{qcircuit}
# \usepackage{graphicx}
#
# \begin{document}
# \scalebox{1.0}{
# \Qcircuit @C=1.0em @R=0.2em @!R { \\
# 	 	\nghost{{Clock\;Register}_{0} :  } & \lstick{{Clock\;Register}_{0} :  } & \gate{\mathrm{H}} & \qw & \qw & \qw & \ctrl{4} & \multigate{3}{\mathrm{IQFT}}_<<<{0} & \meter & \qw & \qw & \qw & \qw & \qw\\
# 	 	\nghost{{Clock\;Register}_{1} :  } & \lstick{{Clock\;Register}_{1} :  } & \gate{\mathrm{H}} & \qw & \qw & \ctrl{3} & \qw & \ghost{\mathrm{IQFT}}_<<<{1} & \qw & \meter & \qw & \qw & \qw & \qw\\
# 	 	\nghost{{Clock\;Register}_{2} :  } & \lstick{{Clock\;Register}_{2} :  } & \gate{\mathrm{H}} & \qw & \ctrl{2} & \qw & \qw & \ghost{\mathrm{IQFT}}_<<<{2} & \qw & \qw & \meter & \qw & \qw & \qw\\
# 	 	\nghost{{Clock\;Register}_{3} :  } & \lstick{{Clock\;Register}_{3} :  } & \gate{\mathrm{H}} & \ctrl{1} & \qw & \qw & \qw & \ghost{\mathrm{IQFT}}_<<<{3} & \qw & \qw & \qw & \meter & \qw & \qw\\
# 	 	\nghost{{Work\;Register} :  } & \lstick{{Work\;Register} :  } & \qw & \gate{\mathrm{U\string^1}} & \gate{\mathrm{U\string^2}} & \gate{\mathrm{U\string^4}} & \gate{\mathrm{U\string^8}} & \qw & \qw & \qw & \qw & \qw & \qw & \qw\\
# 	 	\nghost{\mathrm{{Output} :  }} & \lstick{\mathrm{{Output} :  }} & \lstick{/_{_{4}}} \cw & \cw & \cw & \cw & \cw & \cw & \dstick{_{_{\hspace{0.0em}0}}} \cw \ar @{<=} [-5,0] & \dstick{_{_{\hspace{0.0em}1}}} \cw \ar @{<=} [-4,0] & \dstick{_{_{\hspace{0.0em}2}}} \cw \ar @{<=} [-3,0] & \dstick{_{_{\hspace{0.0em}3}}} \cw \ar @{<=} [-2,0] & \cw & \cw\\
# \\ }}
# \end{document}

# %%
cU = U.control(clockRegisterSize,label='U')

# %%
cU.to_gate()
# Out:
# Instruction(name='c_circuit-234', num_qubits=5, num_clbits=0, params=[])

# %%
cU.num_qubits
# Out:
# 5

# %%
U = QuantumCircuit(workRegister,name='U').to_gate()

# %%
cU = U.control(clockRegister)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_49480\321647244.py in <module>
# ----> 1 cU = U.control(clockRegister)
#
# ~\anaconda3\lib\site-packages\qiskit\circuit\gate.py in control(self, num_ctrl_qubits, label, ctrl_state)
#     119         from .add_control import add_control
#     120
# --> 121         return add_control(self, num_ctrl_qubits, label, ctrl_state)
#     122
#     123     @staticmethod
#
# ~\anaconda3\lib\site-packages\qiskit\circuit\add_control.py in add_control(operation, num_ctrl_qubits, label, ctrl_state)
#      53     """
#      54     if ctrl_state is None:
# ---> 55         ctrl_state = 2**num_ctrl_qubits - 1
#      56     if isinstance(operation, UnitaryGate):
#      57         # attempt decomposition
#
# TypeError: unsupported operand type(s) for ** or pow(): 'int' and 'QuantumRegister'

# %%
myCircuit.qubits[:] == clockRegister[:]+workRegister[:]
# Out:
# True

# %%
clockRegister[:]+workRegister[:]
# Out:
# [Qubit(QuantumRegister(4, 'q22'), 0),
#  Qubit(QuantumRegister(4, 'q22'), 1),
#  Qubit(QuantumRegister(4, 'q22'), 2),
#  Qubit(QuantumRegister(4, 'q22'), 3),
#  Qubit(QuantumRegister(1, 'q23'), 0)]

# %%
[myCircuit.qubits[:]]
# Out:
# [[Qubit(QuantumRegister(4, 'q22'), 0),
#   Qubit(QuantumRegister(4, 'q22'), 1),
#   Qubit(QuantumRegister(4, 'q22'), 2),
#   Qubit(QuantumRegister(4, 'q22'), 3),
#   Qubit(QuantumRegister(1, 'q23'), 0)]]
